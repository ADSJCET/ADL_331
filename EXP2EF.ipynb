# %%
import seaborn as sea

# %%
data = sea.load_dataset("iris")

x = "sepal_length"
y = "sepal_width"

sea.lineplot(x=x, y=y, data=data)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
import pandas as pd

# %%
data = [1,3,4,5,6,2,9]

s = pd.Series(data)
index = ["a", "b", "c", "d", "e", "f", "g"]

result = pd.Series(data, index)
print(result)
# Out:
# a    1
# b    3
# c    4
# d    5
# e    6
# f    2
# g    9
# dtype: int64
