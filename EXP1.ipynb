# %%
import statistics as st
import numpy as np
import matplotlib.pyplot as plot

# %%
data = [1,2,3,4,5,4,9,4]

print("Mean", st.mean(data))
print("Median", st.median(data))
print("Mode", st.mode(data))
# Out:
# Mean 4
# Median 4.0
# Mode 4

# %%
print("STD Deviation", np.std(data))
print("Percentile", np.percentile(data,10))
# Out:
# STD Deviation 2.23606797749979
# Percentile 1.7000000000000002

# %%
x = np.linspace(1, 50, 200)
mean = np.mean(x)
sd = np.std(x)

prob_density = (np.pi * sd) * np.exp(-0.5 * ((x - mean) / sd) ** 2)

# %%
plot.plot(x, prob_density)
plot.title("Normal Ditribution")
plot.show()
